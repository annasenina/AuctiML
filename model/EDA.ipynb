# %%
1+2
# Out:
# 3

# %%
import pandas as pd

# %%
PATH = "../"
PATH_DATASET = PATH + "datasets/"
torgi_filename = PATH_DATASET + "torgi_dataset.csv"

# %%
torgi_df = pd.read_csv(torgi_filename)
torgi_df
# Out:
#      id                    id.1  \
# 0     0  21000002760000000070_1
# 1     0  21000002930000000052_1
# 2     0  21000003150000000052_1
# 3     0  21000003150000000053_1
# 4     0  21000003150000000054_1
# ..   ..                     ...
# 195   0  23000013670000000127_3
# 196   0  23000013670000000127_4
# 197   0  23000013670000000127_5
# 198   0  23000013670000000127_6
# 199   0  23000026730000000009_1
#
#                                                lotName  \
# 0    земельный участок с кадастровым номером 62:08:...
# 1    Аукцион в электронной форме на право заключени...
# 2    Право заключения договора аренды земельного уч...
# 3    Право заключения договора аренды земельного уч...
# 4    Право заключения договора аренды земельного уч...
# ..                                                 ...
# 195  право заключения договора аренды земельного уч...
# 196  право заключения договора аренды земельного уч...
# 197  право заключения договора аренды земельного уч...
# 198  право заключения договора аренды земельного уч...
# 199                                  земельный участок
#
#                    lotStatus  \
# 0                  PUBLISHED
# 1                  PUBLISHED
# 2    APPLICATIONS_SUBMISSION
# 3    APPLICATIONS_SUBMISSION
# 4    APPLICATIONS_SUBMISSION
# ..                       ...
# 195  APPLICATIONS_SUBMISSION
# 196  APPLICATIONS_SUBMISSION
# 197  APPLICATIONS_SUBMISSION
# 198  APPLICATIONS_SUBMISSION
# 199  APPLICATIONS_SUBMISSION
#
#                                               biddForm          noticeNumber  \
# 0        {'code': 'EA', 'name': 'Электронный аукцион'}  21000002760000000070
# 1        {'code': 'EA', 'name': 'Электронный аукцион'}  21000002930000000052
# 2        {'code': 'EA', 'name': 'Электронный аукцион'}  21000003150000000052
# 3        {'code': 'EA', 'name': 'Электронный аукцион'}  21000003150000000053
# 4        {'code': 'EA', 'name': 'Электронный аукцион'}  21000003150000000054
# ..                                                 ...                   ...
# 195      {'code': 'EA', 'name': 'Электронный аукцион'}  23000013670000000127
# 196      {'code': 'EA', 'name': 'Электронный аукцион'}  23000013670000000127
# 197      {'code': 'EA', 'name': 'Электронный аукцион'}  23000013670000000127
# 198      {'code': 'EA', 'name': 'Электронный аукцион'}  23000013670000000127
# 199  {'code': 'IPS', 'name': 'Сообщение о предостав...  23000026730000000009
#
#      lotNumber                                           biddType  \
# 0            1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 1            1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 2            1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 3            1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 4            1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# ..         ...                                                ...
# 195          3  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 196          4  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 197          5  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 198          6  {'code': 'ZK', 'name': 'Аренда и продажа земел...
# 199          1  {'code': 'ZK', 'name': 'Аренда и продажа земел...
#
#      subjectRFCode                                     lotDescription  ...  \
# 0               62  земельный участок с кадастровым номером 62:08:...  ...
# 1               46  Аукцион в электронной форме на право заключени...  ...
# 2               26  площадью 832 кв. м., разрешенное использование...  ...
# 3               26  земельный участок площадью 386 кв. м., разреше...  ...
# 4               26  земельный участок площадью 1270 кв. м., разреш...  ...
# ..             ...                                                ...  ...
# 195             91  право заключения договора аренды земельного уч...  ...
# 196             91  право заключения договора аренды земельного уч...  ...
# 197             91  право заключения договора аренды земельного уч...  ...
# 198             91  право заключения договора аренды земельного уч...  ...
# 199             69  земельный участок площадью 19 463 кв.м, образу...  ...
#
#               biddEndTime                             versionId  \
# 0    2023-10-03T07:00:00Z  018abfac-e177-40f2-9710-555beebe274a
# 1    2023-10-04T14:00:00Z  a60d2635-2b41-485e-867e-128d89971852
# 2    2023-09-28T20:59:00Z  806eb498-0867-4ebc-9bcf-c1046ad9f668
# 3    2023-09-28T20:59:00Z  d07916e0-b9bc-47f1-9493-3bffd140477c
# 4    2023-09-28T20:59:00Z  31e7b4b5-c7ba-41cd-b326-5013b604bad5
# ..                    ...                                   ...
# 195  2023-09-27T06:10:00Z  69ddd7e8-1389-43ff-a6ae-aff33bdaf735
# 196  2023-09-27T06:10:00Z  69ddd7e8-1389-43ff-a6ae-aff33bdaf735
# 197  2023-09-27T06:10:00Z  69ddd7e8-1389-43ff-a6ae-aff33bdaf735
# 198  2023-09-27T06:10:00Z  69ddd7e8-1389-43ff-a6ae-aff33bdaf735
# 199  2023-10-01T21:00:00Z  d36a9eda-a14c-4092-b85a-e3ef1b0a677d
#
#                                       noticeSignedData  \
# 0    {'fileId': '64f1e9127b24875f7af6c28d', 'signat...
# 1    {'fileId': '64f3313f7b24875f7af70446', 'signat...
# 2    {'fileId': '64f1e4414a9ee0449d7de7bc', 'signat...
# 3    {'fileId': '64f1eb867b24875f7af6c351', 'signat...
# 4    {'fileId': '64f1f4985c512c78dfd14e25', 'signat...
# ..                                                 ...
# 195  {'fileId': '64f1f3647b24875f7af6c6ca', 'signat...
# 196  {'fileId': '64f1f3647b24875f7af6c6ca', 'signat...
# 197  {'fileId': '64f1f3647b24875f7af6c6ca', 'signat...
# 198  {'fileId': '64f1f3647b24875f7af6c6ca', 'signat...
# 199  {'fileId': '64f1ef4a8d3e1d5743dec601', 'signat...
#
#                                      egrkns  \
# 0    [{'id': '', 'number': '', 'name': ''}]
# 1    [{'id': '', 'number': '', 'name': ''}]
# 2    [{'id': '', 'number': '', 'name': ''}]
# 3    [{'id': '', 'number': '', 'name': ''}]
# 4    [{'id': '', 'number': '', 'name': ''}]
# ..                                      ...
# 195  [{'id': '', 'number': '', 'name': ''}]
# 196  [{'id': '', 'number': '', 'name': ''}]
# 197  [{'id': '', 'number': '', 'name': ''}]
# 198  [{'id': '', 'number': '', 'name': ''}]
# 199  [{'id': '', 'number': '', 'name': ''}]
#
#                                    egrnInfoRequestList  \
# 0    [{'requestId': '21000002760000000070_1_1_23090...
# 1    [{'requestId': '21000002930000000052_1_1_23090...
# 2    [{'requestId': '21000003150000000052_1_1_23090...
# 3    [{'requestId': '21000003150000000053_1_1_23090...
# 4    [{'requestId': '21000003150000000054_1_1_23090...
# ..                                                 ...
# 195  [{'requestId': '23000013670000000127_3_1_23090...
# 196                                                 []
# 197                                                 []
# 198                                                 []
# 199                                                 []
#
#     noticeFirstVersionPublicationDate isAnnulled depositTreasuryAccount  \
# 0            2023-09-01T13:37:48.107Z      False                    NaN
# 1            2023-09-02T12:58:25.055Z      False                    NaN
# 2            2023-09-01T13:17:37.617Z      False            05213015180
# 3            2023-09-01T13:49:30.706Z      False            05213015180
# 4            2023-09-01T14:27:12.263Z      False            05213015180
# ..                                ...        ...                    ...
# 195          2023-09-01T14:23:10.211Z      False                    NaN
# 196          2023-09-01T14:23:10.211Z      False                    NaN
# 197          2023-09-01T14:23:10.211Z      False                    NaN
# 198          2023-09-01T14:23:10.211Z      False                    NaN
# 199          2023-09-01T14:04:08.949Z      False                    NaN
#
#      isCompound noticeAttributes
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
# ..          ...              ...
# 195         NaN              NaN
# 196         NaN              NaN
# 197         NaN              NaN
# 198         NaN              NaN
# 199         NaN              NaN
#
# [200 rows x 51 columns]
